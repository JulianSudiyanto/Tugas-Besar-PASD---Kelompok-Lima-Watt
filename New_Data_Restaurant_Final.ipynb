# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianSudiyanto/Tugas-Besar-PASD---Kelompok-Lima-Watt/blob/Muthia/New_Data_Restaurant_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("restaurant_sales_data.csv")
df.head(200)
# Out:
#        Order ID Customer ID     Category             Item  Price  Quantity  \
# 0    ORD_705844    CUST_092  Side Dishes       Side Salad    3.0       1.0
# 1    ORD_338528    CUST_021  Side Dishes  Mashed Potatoes    4.0       3.0
# 2    ORD_443849    CUST_029  Main Dishes  Grilled Chicken   15.0       4.0
# 3    ORD_630508    CUST_075       Drinks              NaN    NaN       2.0
# 4    ORD_648269    CUST_031  Main Dishes    Pasta Alfredo   12.0       4.0
# ..          ...         ...          ...              ...    ...       ...
# 195  ORD_930569    CUST_036     Starters     Cheese Fries    5.0       3.0
# 196  ORD_321522    CUST_001  Side Dishes  Mashed Potatoes    4.0       2.0
# 197  ORD_359077    CUST_010       Drinks         Lemonade    3.0       2.0
# 198  ORD_546027    CUST_092     Desserts   Chocolate Cake    6.0       4.0
# 199  ORD_642702    CUST_082     Desserts          Brownie    6.0       2.0
#
#      Order Total  Order Date  Payment Method
# ...

# %%
print("Jumlah data awal:", len(df))
# Out:
# Jumlah data awal: 17534

# %%
df = df.drop(columns=['Order Total', 'Order Date'], errors='ignore')

# %%
duplicate_count = df.duplicated().sum()
print("Jumlah duplikasi:", duplicate_count)
# Out:
# Jumlah duplikasi: 0

# %%
df = df.drop_duplicates()

# %%
print("Jumlah nilai kosong per kolom:")
print(df.isnull().sum())
# Out:
# Jumlah nilai kosong per kolom:
# Order ID             0
# Customer ID          0
# Category             0
# Item              1758
# Price              876
# Quantity           430
# Payment Method    1082
# dtype: int64

# %%
df = df.dropna()

# %%
print("Jumlah nilai kosong per kolom:")
print(df.isnull().sum())
# Out:
# Jumlah nilai kosong per kolom:
# Order ID          0
# Customer ID       0
# Category          0
# Item              0
# Price             0
# Quantity          0
# Payment Method    0
# dtype: int64

# %%
df_200 = df.head(200)

# %%
df_unique = df_200.drop_duplicates()

# %%
df_unique.to_csv("Cleaned_200_Price.csv", index=False)

# %%
print("Jumlah data setelah dibersihkan dan dipotong 200:", len(df_unique))
# Out:
# Jumlah data setelah dibersihkan dan dipotong 200: 200

# %%
df_200 = df.head(200).drop_duplicates().copy()
conversion_rate = 15800
df_200['Price'] = df_200['Price'] * conversion_rate
df_200['Price'] = df_200['Price'].astype(int)
df_200.to_csv("Cleaned_200_Price_Data.csv", index=False)

# %%
df_200
# Out:
#        Order ID Customer ID     Category                Item   Price  \
# 0    ORD_705844    CUST_092  Side Dishes          Side Salad   47400
# 1    ORD_338528    CUST_021  Side Dishes     Mashed Potatoes   63200
# 2    ORD_443849    CUST_029  Main Dishes     Grilled Chicken  237000
# 4    ORD_648269    CUST_031  Main Dishes       Pasta Alfredo  189600
# 5    ORD_381680    CUST_031  Main Dishes              Salmon  284400
# ..          ...         ...          ...                 ...     ...
# 223  ORD_976297    CUST_054  Side Dishes          Side Salad   47400
# 225  ORD_716723    CUST_020     Desserts           Ice Cream   79000
# 227  ORD_210399    CUST_049       Drinks           Coca Cola   39500
# 228  ORD_189902    CUST_052  Side Dishes          Side Salad   47400
# 229  ORD_671854    CUST_055  Main Dishes  Vegetarian Platter  221200
#
#      Quantity  Payment Method
# 0         1.0     Credit Card
# 1         3.0  Digital Wallet
# 2         4.0     Credit Card
# ...

# %%
from google.colab import files
files.download("Cleaned_200_Price_Data.csv")
